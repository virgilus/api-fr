# %% [markdown]
# ## Exercice (niveau moyen)
#
# L’objectif de ce notebook est d’utiliser une API et de générer une carte Leaflet indiquant la position actuelle de l’ISS.
#
# * L’API que nous allons utiliser se trouve ici : [http://api.open-notify.org/](http://api.open-notify.org/)
# * La documentation de Folium est ici : [https://python-visualization.github.io/folium/index.html](https://python-visualization.github.io/folium/index.html), mais le premier chapitre devrait suffire : [https://python-visualization.github.io/folium/quickstart.html](https://python-visualization.github.io/folium/quickstart.html)
#
# **ASTUCES**
#
# * Lorsque vous créez la carte, utilisez les paramètres `location` et `zoom_start` afin qu’elle affiche automatiquement la zone recherchée.
#
# **Bonus**
#
# * Modifiez la propriété *tooltip* du Marker Folium pour qu’elle affiche la latitude et la longitude lorsque vous cliquez dessus.

# %%
# Code here!

# %% [markdown]
# ## Exercice (niveau moyen / difficile)
#
# L’objectif est de tracer une ligne montrant la trajectoire de l’ISS. Pour cela :
#
# * Créez une boucle qui s’exécute toutes les 5 secondes et effectue 12 mesures (latitude, longitude). Votre programme devra donc tourner pendant 1 minute. Stockez toutes ces données dans une liste de tuples.
# * Une fois cela fait, utilisez la fonction `Polyline` de Folium pour tracer la ligne.
#
# **ASTUCES**
#
# * Utilisez la bibliothèque `time` pour faire une pause de 5 secondes entre chaque mesure.
# * Utilisez le paramètre `color` de `Polyline` pour colorer la ligne en rouge — c’est plus clair.
# * Utilisez plusieurs cellules Jupyter. Une fois que vous avez les données (les coordonnées), il n’est plus nécessaire d’attendre 1 minute à chaque modification de la carte.

# %%
# Code here!
