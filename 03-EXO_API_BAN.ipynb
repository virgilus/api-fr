# %% [markdown]
# # Exo pratique : récupérer les coordonnées d'adresses
#
# ## Appel API pour récupérer des coordonnées géographiques
#
# Ecrivez une fonction qui prend en entrée une adresse (stockée sous forme de string) et qui retourne les coordonnées géographiques (latitude et longitude) de cette adresse en utilisant l'API de la base d'adresse nationale.
#
# Documentation :
# https://geoservices.ign.fr/documentation/services/services-geoplateforme/geocodage
#
# Capacités de l'API :
# https://data.geopf.fr/geocodage/getCapabilities

# %%
# Code here
import requests

# %% [markdown]
# ## Géo-codage en masse avec l'API de la base d'adresse nationale
#
# Le dossier "data" contient un fichier nommé "prefectures.csv". Écrivez un script automatisé en python qui récupère les coordonnées (latitude et longitude) de chacune préfectures grâce à l'API de la base d'adresse nationale. Mais cette fois-ci utiliserz le géo-codage en masse pour optimiser les appels API.
#
# Le script doit ensuite enregistrer les résultats dans un nouveau fichier CSV en ajoutant deux colonnes : latitude et longitude.
#
# L'url est celle-ci: https://data.geopf.fr/geocodage/search/csv

# %%
# Code here!
